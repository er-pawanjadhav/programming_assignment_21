# %%
def fun1(a,b):
    if len(a)>0:
        a.pop(0)
        a.append(b)
        return a
    else:
        return "no list has been selected "

a = [105,11,42,4,5,841,84,44]
b = 52

print(f"before list {a} \nafter list {fun1(a,b)}")
# Out:
# before list [105, 11, 42, 4, 5, 841, 84, 44]
# after list [11, 42, 4, 5, 841, 84, 44, 52]
