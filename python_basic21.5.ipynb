# %%
def function1(a):  
    d = []
    for i in a:
        if type(i)==int:
            d.append(i)
    return d

a = [9, 2, "space", "car","master", "lion", 16]

print(function1(a))
# Out:
# [9, 2, 16]
